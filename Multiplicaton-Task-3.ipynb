# %%
a = int(input("Enter first value"))# Multiplication for using user input or int used for integer value.
b = int(input("Enter second value"))
c = a*b
print("Result:-",+c) # For final result print.
# Out:
# Enter first value10
# Enter second value2
# Result:- 20
